# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread("../DATA/00-puppy.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
fix_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_image)

# %%
gray_image = cv2.imread("../DATA/00-puppy.jpg", cv2.IMREAD_GRAYSCALE)

# %%
gray_image.shape
# Out:
# (1300, 1950)

# %%
gray_image.min()
# Out:
# 1

# %%
gray_image.max()
# Out:
# 209

# %%
plt.imshow(gray_image, "gray")

# %%
plt.imshow(fix_image)

# %%
change_image = cv2.resize(fix_image, (1000, 400))

# %%
plt.imshow(change_image)

# %%
new_image = cv2.resize(fix_image, (0,0), fix_image, 0.5, 0.5)

# %%
plt.imshow(new_image)

# %%
new_image.shape
# Out:
# (650, 975, 3)

# %%
flip_y = cv2.flip(fix_image, 0)

# %%
plt.imshow(flip_y)
type(flip_y)
cv2.imwrite("flipyImage.jpg", flip_y)
# Out:
# True

# %%
flip_x = cv2.flip(fix_image, 1)
plt.imshow(flip_x)

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(131)
ax.imshow(fix_image)
ax1 = fig.add_subplot(132)
ax1.imshow(flip_y)
ax2 = fig.add_subplot(133)
ax2.imshow(flip_x)
